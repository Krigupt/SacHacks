# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('data-final.csv', sep='\t')

# %%
df = df.iloc[0:100000]

# %%
df
# Out:
#        EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0       4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1       3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2       2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3       2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4       3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 99995   4.0   2.0   2.0   2.0   4.0   2.0   4.0   2.0   2.0    2.0  ...
# 99996   4.0   3.0   3.0   1.0   4.0   4.0   3.0   3.0   4.0    5.0  ...
# 99997   3.0   1.0   5.0   1.0   4.0   1.0   3.0   5.0   4.0    3.0  ...
# 99998   5.0   1.0   5.0   1.0   5.0   1.0   5.0   1.0   5.0    1.0  ...
# 99999   3.0   1.0   4.0   3.0   4.0   2.0   3.0   3.0   4.0    4.0  ...
#
#                   dateload  screenw  screenh  introelapse  testelapse  \
# ...

# %%
df.to_csv('piplined_data.csv')
